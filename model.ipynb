# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
import pickle
from sklearn.metrics import accuracy_score
from sklearn.metrics.pairwise import cosine_similarity

# %%
bldata = pd.read_csv("bloodbank.csv", encoding = "latin1")
bldata.head()
# Out:
#    Sr No                                    Blood Bank Name  \
# 0      1                      G.B. Pant Hospital Blood bank
# 1      2                                I.N.H.S. Dhanvantri
# 2      3                    Pillar Health Centre Blood Bank
# 3      4  Indian Red Cross Society Blood Bank, District ...
# 4      5             Government General Hospital Blood Bank
#
#                          State       District        City  \
# 0  Andaman And Nicobar Islands  SOUTH ANDAMAN  Port Blair
# 1  Andaman And Nicobar Islands  SOUTH ANDAMAN  Port Blair
# 2  Andaman And Nicobar Islands  SOUTH ANDAMAN  Port Blair
# 3               Andhra Pradesh      ANANTAPUR   Anantapur
# 4               Andhra Pradesh      ANANTAPUR  Ananthapur
#
#                                              Address Pincode  \
# 0  Atlanta Point\r\nNear Cellular Jail\r\nP.O. Ab...  744104
# 1  Ashvini Nagar, Port Blair, Andaman and Nicobar...  744103
# 2  Lamba Line,\r\nP.B. 526,\r\nP.O. Junglighat, \...  744104
# 3  Near JNTU Engeneering College, Sarada Nagar, A...  515002
# 4            Government General Hospital, Ananthapur  515001
#
#                    Contact No      Mobile      Helpline  ...  \
# 0                03192 230628  9434266561           102  ...
# 1                03192 248759  8001452200           NaN  ...
# 2  03192 233193, 03192 233993  9474247585  03192 233193  ...
# 3                08554 246344  9441192365           NaN  ...
# 4                08554 275024  9866695858           NaN  ...
#
#    Qualification Nodal Officer    Category  Blood Component Available  \
# 0                          NaN  Government                        YES
# 1         MBBS, MD (Pathology)  Government                         NO
# 2          MBBS, MD (Medicine)     Charity                         NO
# 3                MBBS, MD, DCP     Charity                        YES
# 4         MBBS, MD (Pathology)  Government                        YES
#
#    Apheresis  Service Time            License #  Date License Obtained  \
# 0         NO          24X7         DL1/CLAA/ANI              14.6.1996
# 1         NO          24X7         DL2/CLAA/ANI             14.06.1996
# 2         NO          24X7         DL3/CLAA/ANI             08.09.2010
# 3         NO          24x7  13/ATP/AP/2005/BB/R             22.11.2005
# 4         NO          24x7    50/ATP/AP/97/BB/R             28.01.1997
#
#    Date of Renewal   Latitude  Longitude
# 0       01.01.2012  11.675442  92.747338
# 1       31.12.2016  11.649693  92.717418
# 2       10.06.2015  11.653229  92.730714
# 3       21.11.2015  14.654936  77.609915
# 4       01.01.2013  14.671459  77.596684
#
# [5 rows x 27 columns]

# %% [markdown]
# # Step first is Data Cleaning

# %%
bldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Sr No                         2823 non-null   int64
#  1    Blood Bank Name              2823 non-null   object
#  2    State                        2823 non-null   object
#  3    District                     2822 non-null   object
#  4    City                         2803 non-null   object
#  5    Address                      2754 non-null   object
#  6   Pincode                       2651 non-null   object
#  7    Contact No                   2524 non-null   object
#  8    Mobile                       2149 non-null   object
#  9    Helpline                     209 non-null    object
#  10   Fax                          494 non-null    object
#  11   Email                        1557 non-null   object
#  12   Website                      584 non-null    object
#  13   Nodal Officer                2237 non-null   object
#  14   Contact Nodal Officer        1322 non-null   object
#  15   Mobile Nodal Officer         2140 non-null   object
#  16   Email Nodal Officer          1991 non-null   object
#  17   Qualification Nodal Officer  1851 non-null   object
#  18   Category                     2744 non-null   object
#  19   Blood Component Available    2405 non-null   object
#  20   Apheresis                    2055 non-null   object
#  21   Service Time                 2421 non-null   object
#  22   License #                    2229 non-null   object
#  23   Date License Obtained        2125 non-null   object
#  24   Date of Renewal              2143 non-null   object
#  25   Latitude                     2823 non-null   float64
#  26   Longitude                    2823 non-null   float64
# dtypes: float64(2), int64(1), object(24)
# memory usage: 595.6+ KB

# %%
bldata.isna().sum()
# Out:
# Sr No                              0
#  Blood Bank Name                   0
#  State                             0
#  District                          1
#  City                             20
#  Address                          69
# Pincode                          172
#  Contact No                      299
#  Mobile                          674
#  Helpline                       2614
#  Fax                            2329
#  Email                          1266
#  Website                        2239
#  Nodal Officer                   586
#  Contact Nodal Officer          1501
#  Mobile Nodal Officer            683
#  Email Nodal Officer             832
#  Qualification Nodal Officer     972
#  Category                         79
#  Blood Component Available       418
#  Apheresis                       768
#  Service Time                    402
#  License #                       594
#  Date License Obtained           698
#  Date of Renewal                 680
#  Latitude                          0
#  Longitude                         0
# dtype: int64

# %%
bldata.shape
# Out:
# (2823, 27)

# %%
# copy data for modification
data = bldata.copy()

# %%
# remove white spaces from columns 
data.columns = data.columns.str.strip()
data.columns.tolist()
# Out:
# ['Sr No',
#  'Blood Bank Name',
#  'State',
#  'District',
#  'City',
#  'Address',
#  'Pincode',
#  'Contact No',
#  'Mobile',
#  'Helpline',
#  'Fax',
#  'Email',
#  'Website',
#  'Nodal Officer',
#  'Contact Nodal Officer',
#  'Mobile Nodal Officer',
#  'Email Nodal Officer',
#  'Qualification Nodal Officer',
#  'Category',
#  'Blood Component Available',
#  'Apheresis',
#  'Service Time',
#  'License #',
#  'Date License Obtained',
#  'Date of Renewal',
#  'Latitude',
#  'Longitude']

# %%
data.drop(["Date of Renewal","Qualification Nodal Officer","Category","Blood Component Available","Apheresis","Service Time","License #","Date License Obtained","Date of Renewal"], axis = 1, inplace = True)
data.columns.tolist()
# Out:
# ['Sr No',
#  'Blood Bank Name',
#  'State',
#  'District',
#  'City',
#  'Address',
#  'Pincode',
#  'Contact No',
#  'Mobile',
#  'Helpline',
#  'Fax',
#  'Email',
#  'Website',
#  'Nodal Officer',
#  'Contact Nodal Officer',
#  'Mobile Nodal Officer',
#  'Email Nodal Officer',
#  'Latitude',
#  'Longitude']

# %%
# remove rows which does not have any location
data.dropna(subset=['City','District'], inplace = True)
data.isna().sum()
# Out:
# Sr No                       0
# Blood Bank Name             0
# State                       0
# District                    0
# City                        0
# Address                    67
# Pincode                   166
# Contact No                297
# Mobile                    662
# Helpline                 2593
# Fax                      2309
# Email                    1248
# Website                  2218
# Nodal Officer             573
# Contact Nodal Officer    1488
# Mobile Nodal Officer      669
# Email Nodal Officer       818
# Latitude                    0
# Longitude                   0
# dtype: int64

# %%
# remove rows where user can't contact
missing_data = data[data['Mobile'].isna() & data['Helpline'].isna() & data['Contact No'].isna()]
data.drop(missing_data.index, inplace = True)
data.drop(columns=['Fax'], axis = 1, inplace=True)

# %%
data.drop(['Website'],axis = 1, inplace = True)
data.head(10)
# Out:
#    Sr No                                    Blood Bank Name  \
# 0      1                      G.B. Pant Hospital Blood bank
# 1      2                                I.N.H.S. Dhanvantri
# 2      3                    Pillar Health Centre Blood Bank
# 3      4  Indian Red Cross Society Blood Bank, District ...
# 4      5             Government General Hospital Blood Bank
# 5      6                           Indian Red Cross Society
# 6      7        Rural Development Trust Hospital Blood Bank
# 7      8          South Central Railway Hospital Blood Bank
# 8      9                Indian Red Cross Society Blood Bank
# 9     10  Indian Red Cross Society Blood bank RCH -II KA...
#
#                          State       District          City  \
# 0  Andaman And Nicobar Islands  SOUTH ANDAMAN    Port Blair
# 1  Andaman And Nicobar Islands  SOUTH ANDAMAN    Port Blair
# 2  Andaman And Nicobar Islands  SOUTH ANDAMAN    Port Blair
# 3               Andhra Pradesh      ANANTAPUR     Anantapur
# 4               Andhra Pradesh      ANANTAPUR    Ananthapur
# 5               Andhra Pradesh      ANANTAPUR    Ananthapur
# 6               Andhra Pradesh      ANANTAPUR  Bathalapalli
# 7               Andhra Pradesh      ANANTAPUR      Guntakal
# 8               Andhra Pradesh      ANANTAPUR      Hindupur
# 9               Andhra Pradesh      ANANTAPUR        Kadiri
#
#                                              Address Pincode  \
# 0  Atlanta Point\r\nNear Cellular Jail\r\nP.O. Ab...  744104
# 1  Ashvini Nagar, Port Blair, Andaman and Nicobar...  744103
# 2  Lamba Line,\r\nP.B. 526,\r\nP.O. Junglighat, \...  744104
# 3  Near JNTU Engeneering College, Sarada Nagar, A...  515002
# 4            Government General Hospital, Ananthapur  515001
# 5  Blood Bank Medical Officer,Blood Bank, Indian ...  515001
# 6              Kadiri Road, Bathalapalli, Ananthapur  515661
# 7     S.C. Railway Hospital, Guntakal, Ananthapuramu  515801
# 8  Government General Hospital Blood Bank, Hindup...  515201
# 9  Ground Floor, APVVP (Government General Hospit...  515591
#
#                    Contact No                     Mobile      Helpline  \
# 0                03192 230628                 9434266561           102
# 1                03192 248759                 8001452200           NaN
# 2  03192 233193, 03192 233993                 9474247585  03192 233193
# 3                08554 246344                 9441192365           NaN
# 4                08554 275024                 9866695858           NaN
# 5                  8554246344  Dist.Secretary 9866023293           NaN
# 6                08559 244259                 9493268861           NaN
# 7                08552 227166                 9701374501           NaN
# 8                08556 225900                        NaN           NaN
# 9                08494 221544                 9989738689           NaN
#
#                                Email  \
# 0                 bbgbpant@gmail.com
# 1                                NaN
# 2      pillarbloodbank2016@gmail.com
# 3                                NaN
# 4          bloodbankgghatp@gmail.com
# 5  ircsbloodbank.anantapur@gmail.com
# 6                                NaN
# 7                                NaN
# 8                  ircshup@gmail.com
# 9               kadiriircs@gmail.com
#
#                                 Nodal Officer       Contact Nodal Officer  \
# 0                          Dr.Ganesh Samaddar                03192 230628
# 1                           Dr.Smiriti Mathur                03192 248759
# 2                          Dr. Sr. Cross Mary  03192 233193, 03192 233993
# 3  Dr.G. Parvathi & Dr.G. Ramanjaneyulu Naidu                         NaN
# 4               Dr. Shiva kumar & Dr. Swapna                 08554 275024
# 5                                         NaN                         NaN
# 6                    Dr. Hariharanadha Sharma                         NaN
# 7                                         NaN                         NaN
# 8                               Dr. M. Satyam                  9490978739
# 9                      Dr. G. P. Subbrayudu\t                         NaN
#
#        Mobile Nodal Officer                Email Nodal Officer   Latitude  \
# 0                9434266561          ganeshsamadder7@gmail.com  11.675442
# 1                8001452200                 mesmriti@yahoo.com  11.649693
# 2                9474247585         crossgracy2003@yahoo.co.in  11.653229
# 3  09441125444, 09440286555  ircsbloodbank.anantapur@gmail.com  14.654936
# 4  09866695858, 09912938380          bloodbankgghatp@gmail.com  14.671459
# 5                       NaN                                NaN  14.681888
# 6                9177155517           syanakishore@yahoo.co.in  14.652907
# 7                       NaN  scrhbloodbank@gmail.com\t\t\t\t\t  15.172889
# 8                9490978739                  ircshup@gmail.com  13.832533
# 9                9989738689               kadiriircs@gmail.com  14.113089
#
#    Longitude
# 0  92.747338
# 1  92.717418
# 2  92.730714
# 3  77.609915
# 4  77.596684
# 5  77.600591
# 6  77.618826
# 7  77.366103
# 8  77.492214
# 9  78.157366

# %%
df1 = pd.DataFrame(columns= ['name','latitude','longitude'])
df1['name'] = data['Blood Bank Name']
df1['latitude'] = data['Latitude']
df1['longitude'] = data['Longitude']
df1.head()
# Out:
#                                                 name   latitude  longitude
# 0                      G.B. Pant Hospital Blood bank  11.675442  92.747338
# 1                                I.N.H.S. Dhanvantri  11.649693  92.717418
# 2                    Pillar Health Centre Blood Bank  11.653229  92.730714
# 3  Indian Red Cross Society Blood Bank, District ...  14.654936  77.609915
# 4             Government General Hospital Blood Bank  14.671459  77.596684

# %% [markdown]
# # Step 2 Data Manupulation

# %%
data['contact info'] = data['Contact No'].fillna('') + ', ' + data['Mobile'].fillna('') + ', ' + data['Helpline'].fillna('') + ', ' + data['Email'].fillna('')

data.drop(["Contact No","Mobile","Helpline","Email","Sr No"], axis = 1, inplace = True)

# %%
data.dropna(subset=['Pincode'], inplace = True)
data.shape
# Out:
# (2584, 13)

# %%
data['loc'] = data['State'].fillna('') +' ' + data['District'].fillna('') + ' ' + data['City'].fillna('') + ' ' + data['Pincode'].fillna('')
# df['address'] = df['Address'].fillna('') + ', ' + df['City'].fillna('') + '- ' + df['Pincode'].fillna('') + ', ' + df['District'].fillna('')

# %%
data['loc'] = data['loc'].str.lower()

# %%
# data['loc'] = data['loc'].str.replace(' ', '')

# %%
data.head(5)
# Out:
#                                      Blood Bank Name  \
# 0                      G.B. Pant Hospital Blood bank
# 1                                I.N.H.S. Dhanvantri
# 2                    Pillar Health Centre Blood Bank
# 3  Indian Red Cross Society Blood Bank, District ...
# 4             Government General Hospital Blood Bank
#
#                          State       District        City  \
# 0  Andaman And Nicobar Islands  SOUTH ANDAMAN  Port Blair
# 1  Andaman And Nicobar Islands  SOUTH ANDAMAN  Port Blair
# 2  Andaman And Nicobar Islands  SOUTH ANDAMAN  Port Blair
# 3               Andhra Pradesh      ANANTAPUR   Anantapur
# 4               Andhra Pradesh      ANANTAPUR  Ananthapur
#
#                                              Address Pincode  \
# 0  Atlanta Point\r\nNear Cellular Jail\r\nP.O. Ab...  744104
# 1  Ashvini Nagar, Port Blair, Andaman and Nicobar...  744103
# 2  Lamba Line,\r\nP.B. 526,\r\nP.O. Junglighat, \...  744104
# 3  Near JNTU Engeneering College, Sarada Nagar, A...  515002
# 4            Government General Hospital, Ananthapur  515001
#
#                                 Nodal Officer       Contact Nodal Officer  \
# 0                          Dr.Ganesh Samaddar                03192 230628
# 1                           Dr.Smiriti Mathur                03192 248759
# 2                          Dr. Sr. Cross Mary  03192 233193, 03192 233993
# 3  Dr.G. Parvathi & Dr.G. Ramanjaneyulu Naidu                         NaN
# 4               Dr. Shiva kumar & Dr. Swapna                 08554 275024
#
#        Mobile Nodal Officer                Email Nodal Officer   Latitude  \
# 0                9434266561          ganeshsamadder7@gmail.com  11.675442
# 1                8001452200                 mesmriti@yahoo.com  11.649693
# 2                9474247585         crossgracy2003@yahoo.co.in  11.653229
# 3  09441125444, 09440286555  ircsbloodbank.anantapur@gmail.com  14.654936
# 4  09866695858, 09912938380          bloodbankgghatp@gmail.com  14.671459
#
#    Longitude                                       contact info  \
# 0  92.747338  03192 230628, 9434266561, 102, bbgbpant@gmail.com
# 1  92.717418                       03192 248759, 8001452200, ,
# 2  92.730714  03192 233193, 03192 233993, 9474247585, 03192 ...
# 3  77.609915                       08554 246344, 9441192365, ,
# 4  77.596684  08554 275024, 9866695858, , bloodbankgghatp@gm...
#
#                                                  loc
# 0  andaman and nicobar islands south andaman port...
# 1  andaman and nicobar islands south andaman port...
# 2  andaman and nicobar islands south andaman port...
# 3          andhra pradesh anantapur anantapur 515002
# 4         andhra pradesh anantapur ananthapur 515001

# %% [markdown]
# # model Logic Building

# %%
cv = CountVectorizer(max_features = 3000)

# %%
vectors = cv.fit_transform(data['loc']).toarray()

# %%
similarity = cosine_similarity(vectors)

# %%
sorted(list(enumerate(similarity[0])), reverse = True, key = lambda x:x[1])[:3]
# Out:
# [(0, 1.0), (2, 1.0), (1, 0.9090909090909093)]

# %%
def nearest_bank_recommendation(user_query):
    bank_index = data[data['loc'] == user_query].index[0]
    distance = similarity[bank_index]
    bank_list = sorted(list(enumerate(distance)), reverse = True, key = lambda x:x[1])[:3]
    
    for i in bank_list:
        print("- ", data.iloc[i[0]]['Blood Bank Name'])
        print("  State:", data.iloc[i[0]]['State'])
        print("  City:", data.iloc[i[0]]['City'])
        print("  Pincode:", data.iloc[i[0]]['Pincode'])
        print("  Contact Info:", data.iloc[i[0]]['contact info'])
        print("  Nodal Officer:", data.iloc[i[0]]['Contact Nodal Officer'])
        print("  Nodal officer Mobile:", data.iloc[i[0]]['Mobile Nodal Officer'])
        print("  Nodal Officer Email:", data.iloc[i[0]]['Email Nodal Officer'])
        print()

    
#     recommended = bank_list['Blood Bank Name','State', 'City']

# %%
nearest_bank_recommendation('andhra pradesh anantapur anantapur 515002')
# data['loc'][3]
# Out:
# -  Indian Red Cross Society Blood Bank, District Branch
#   State: Andhra Pradesh
#   City: Anantapur
#   Pincode: 515002
#   Contact Info: 08554 246344, 9441192365, ,
#   Nodal Officer: nan
#   Nodal officer Mobile: 09441125444, 09440286555
#   Nodal Officer Email: ircsbloodbank.anantapur@gmail.com
#
# -  Government General Hospital Blood Bank
#   State: Andhra Pradesh
#   City: Ananthapur
#   Pincode: 515001
#   Contact Info: 08554 275024, 9866695858, , bloodbankgghatp@gmail.com
#   Nodal Officer: 08554 275024
#   Nodal officer Mobile: 09866695858, 09912938380
#   Nodal Officer Email: bloodbankgghatp@gmail.com
#
# -  Indian Red Cross Society
#   State: Andhra Pradesh
#   City: Ananthapur
#   Pincode: 515001
#   Contact Info: 8554246344, Dist.Secretary 9866023293, , ircsbloodbank.anantapur@gmail.com
#   Nodal Officer: nan
#   Nodal officer Mobile: nan
#   Nodal Officer Email: nan

# %%
pickle.dump(data.to_dict(), open('bank.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))
